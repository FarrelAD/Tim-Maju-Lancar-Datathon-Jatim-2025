# %% [markdown]
# # Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from pathlib import Path

# %% [markdown]
# # Year 2025

# %% [markdown]
# ## All Province in Indonesia

# %%
df_indonesia_slb_20251 = pd.read_csv('../data/dapo-kemdikdasmen/2025-1/ALL/indonesia-slb-csv.csv')
df_indonesia_slb_20251
# Out:
#                   provinsi        kabupaten/kota                   kecamatan  \
# 0               Prov. Aceh       Kab. Aceh Barat         Kec. Johan Pahlawan
# 1               Prov. Aceh       Kab. Aceh Barat             Kec. Panton Reu
# 2               Prov. Aceh       Kab. Aceh Barat               Kec. Samatiga
# 3               Prov. Aceh  Kab. Aceh Barat Daya                  Kec. Susoh
# 4               Prov. Aceh       Kab. Aceh Besar             Kec. Ingin Jaya
# ...                    ...                   ...                         ...
# 2432  Prov. Sumatera Utara          Kota Sibolga        Kec. Sibolga Selatan
# 2433  Prov. Sumatera Utara    Kota Tanjung Balai  Kec. Tanjung Balai Selatan
# 2434  Prov. Sumatera Utara    Kota Tebing Tinggi                Kec. Bajenis
# 2435  Prov. Sumatera Utara    Kota Tebing Tinggi           Kec. Padang Hilir
# 2436  Prov. Sumatera Utara    Kota Tebing Tinggi            Kec. Padang Hulu
#
#                                sekolah  rombel  guru_kelas  guru_matematika  \
# 0                  SLB NEGERI MEULABOH      29          14                0
# 1                  SLB Nadiatul Khairi      12           3                4
# 2                      SLB Rahmatillah      23           6                1
# 3           SLB NEGERI Aceh Barat Daya      20          11                1
# 4     SLB Negeri Pembina Provinsi Aceh      49          34                3
# ...                                ...     ...         ...              ...
# 2432                SLB Negeri Sibolga      28          10                3
# 2433          SLB Negeri Tanjung Balai      20          10                1
# 2434    SLB SWASTA YAPSI TEBING TINGGI      14          12                0
# 2435              SLB SWASTA KASIH IBU      23           4                0
# 2436          SLB Negeri Tebing Tinggi      34          17                0
#
#       guru_bahasa_indonesia  guru_bahasa_inggris  guru_sejarah_indonesia  ...  \
# 0                         1                    1                       0  ...
# 1                         4                    3                       0  ...
# 2                         2                    5                       0  ...
# 3                         0                    2                       0  ...
# 4                         1                    3                       0  ...
# ...                     ...                  ...                     ...  ...
# 2432                      2                    3                       0  ...
# 2433                      0                    0                       0  ...
# 2434                      0                    0                       0  ...
# 2435                      0                    0                       0  ...
# 2436                      0                    0                       0  ...
#
#       sumber_air_minum  kecukupan_air_bersih  jamban_kk  tipe_jamban  \
# 0                  NaN                   NaN        NaN          NaN
# 1                  NaN                   NaN        NaN          NaN
# 2                  NaN                   NaN        NaN          NaN
# 3                  NaN                   NaN        NaN          NaN
# 4                  NaN                   NaN        NaN          NaN
# ...                ...                   ...        ...          ...
# 2432               NaN                   NaN        NaN          NaN
# 2433               NaN                   NaN        NaN          NaN
# 2434               NaN                   NaN        NaN          NaN
# 2435               NaN                   NaN        NaN          NaN
# 2436               NaN                   NaN        NaN          NaN
#
#       jml_hari_cuci_tangan  jml_wastafel  jml_wastafel_rusak  \
# 0                      NaN           NaN                 NaN
# 1                      NaN           NaN                 NaN
# 2                      NaN           NaN                 NaN
# 3                      NaN           NaN                 NaN
# 4                      NaN           NaN                 NaN
# ...                    ...           ...                 ...
# 2432                   NaN           NaN                 NaN
# 2433                   NaN           NaN                 NaN
# 2434                   NaN           NaN                 NaN
# 2435                   NaN           NaN                 NaN
# 2436                   NaN           NaN                 NaN
#
#       air_mengalir_wastafel  memiliki_drainase  menguras_tangki_septik
# 0                       NaN                NaN                     NaN
# 1                       NaN                NaN                     NaN
# 2                       NaN                NaN                     NaN
# 3                       NaN                NaN                     NaN
# 4                       NaN                NaN                     NaN
# ...                     ...                ...                     ...
# 2432                    NaN                NaN                     NaN
# 2433                    NaN                NaN                     NaN
# 2434                    NaN                NaN                     NaN
# 2435                    NaN                NaN                     NaN
# 2436                    NaN                NaN                     NaN
#
# [2437 rows x 100 columns]

# %%
df_indonesia_slb_20251_groupby_provinsi= df_indonesia_slb_20251.groupby('provinsi').sum(numeric_only=True)
df_indonesia_slb_20251_groupby_provinsi
# Out:
#                                  rombel  guru_kelas  guru_matematika  \
# provinsi
# Prov. Aceh                         1547         797               56
# Prov. Bali                          626         220               29
# Prov. Banten                       2073        1107               49
# Prov. Bengkulu                      375         234               14
# Prov. D.I. Yogyakarta              1348         810               17
# Prov. D.K.I. Jakarta               1395        1131              109
# Prov. Gorontalo                     259         102                4
# Prov. Jambi                         589         301               29
# Prov. Jawa Barat                   7821        4371               96
# Prov. Jawa Tengah                  3944        2109               65
# Prov. Jawa Timur                   5652        3238              199
# Prov. Kalimantan Barat              413         229               17
# Prov. Kalimantan Selatan            882         627               53
# Prov. Kalimantan Tengah             390         301               15
# Prov. Kalimantan Timur              577         325               25
# Prov. Kalimantan Utara              186          65                3
# Prov. Kepulauan Bangka Belitung     371         143               13
# Prov. Kepulauan Riau                490         233               14
# Prov. Lampung                       626         363                5
# Prov. Maluku                        200          95               11
# Prov. Maluku Utara                  257         191                2
# Prov. Nusa Tenggara Barat          1107         510               41
# Prov. Nusa Tenggara Timur           875         413               55
# Prov. Papua                          81          55                0
# Prov. Papua Barat                    15           8                0
# Prov. Papua Barat Daya               69          35                2
# Prov. Papua Selatan                  48          18                0
# Prov. Papua Tengah                   51          13                0
# Prov. Riau                         1073         495               34
# Prov. Sulawesi Barat                379         173               14
# Prov. Sulawesi Selatan             1601         867               62
# Prov. Sulawesi Tengah               545         230               22
# Prov. Sulawesi Tenggara             850         435               58
# Prov. Sulawesi Utara                404         247               22
# Prov. Sumatera Barat               2160        1279               76
# Prov. Sumatera Selatan              669         422               49
# Prov. Sumatera Utara               1255         716               57
#
#                                  guru_bahasa_indonesia  guru_bahasa_inggris  \
# provinsi
# Prov. Aceh                                          53                   61
# Prov. Bali                                          32                   21
# Prov. Banten                                        55                   35
# Prov. Bengkulu                                      16                   21
# Prov. D.I. Yogyakarta                               60                   62
# Prov. D.K.I. Jakarta                               110                   31
# Prov. Gorontalo                                      1                   12
# Prov. Jambi                                         26                   30
# Prov. Jawa Barat                                    99                  116
# Prov. Jawa Tengah                                   45                   63
# Prov. Jawa Timur                                   198                  217
# Prov. Kalimantan Barat                              23                   11
# Prov. Kalimantan Selatan                            37                   27
# Prov. Kalimantan Tengah                             13                   20
# Prov. Kalimantan Timur                              26                   33
# Prov. Kalimantan Utara                               3                    3
# Prov. Kepulauan Bangka Belitung                     15                    6
# Prov. Kepulauan Riau                                13                   19
# Prov. Lampung                                        3                   11
# Prov. Maluku                                         6                    1
# Prov. Maluku Utara                                   4                    3
# Prov. Nusa Tenggara Barat                           57                   40
# Prov. Nusa Tenggara Timur                           52                   45
# Prov. Papua                                          0                    0
# Prov. Papua Barat                                    0                    1
# Prov. Papua Barat Daya                               4                    2
# Prov. Papua Selatan                                  1                    0
# Prov. Papua Tengah                                   1                    1
# Prov. Riau                                          41                   26
# Prov. Sulawesi Barat                                27                   16
# Prov. Sulawesi Selatan                              62                   76
# Prov. Sulawesi Tengah                               27                   21
# Prov. Sulawesi Tenggara                             58                   49
# Prov. Sulawesi Utara                                27                    8
# Prov. Sumatera Barat                                73                   87
# Prov. Sumatera Selatan                              43                   29
# Prov. Sumatera Utara                                44                   36
#
#                                  guru_sejarah_indonesia  guru_pkn  \
# provinsi
# Prov. Aceh                                            0        35
# Prov. Bali                                            0        21
# Prov. Banten                                          0        25
# Prov. Bengkulu                                        0         6
# Prov. D.I. Yogyakarta                                 0        94
# Prov. D.K.I. Jakarta                                  0       160
# Prov. Gorontalo                                       0         2
# Prov. Jambi                                           0        19
# Prov. Jawa Barat                                      0        47
# Prov. Jawa Tengah                                     0        30
# Prov. Jawa Timur                                      0       168
# Prov. Kalimantan Barat                                0        19
# Prov. Kalimantan Selatan                              0        36
# Prov. Kalimantan Tengah                               0        10
# Prov. Kalimantan Timur                                0        24
# Prov. Kalimantan Utara                                0         2
# Prov. Kepulauan Bangka Belitung                       0        11
# Prov. Kepulauan Riau                                  0        10
# Prov. Lampung                                         0         2
# Prov. Maluku                                          0         3
# Prov. Maluku Utara                                    0         1
# Prov. Nusa Tenggara Barat                             0        57
# Prov. Nusa Tenggara Timur                             0        54
# Prov. Papua                                           0         1
# Prov. Papua Barat                                     0         0
# Prov. Papua Barat Daya                                0         1
# Prov. Papua Selatan                                   0         1
# Prov. Papua Tengah                                    0         1
# Prov. Riau                                            0        37
# Prov. Sulawesi Barat                                  0        16
# Prov. Sulawesi Selatan                                0        42
# Prov. Sulawesi Tengah                                 0        19
# Prov. Sulawesi Tenggara                               0        50
# Prov. Sulawesi Utara                                  0        18
# Prov. Sumatera Barat                                  0        53
# Prov. Sumatera Selatan                                0        30
# Prov. Sumatera Utara                                  0        28
#
#                                  guru_penjaskes  guru_agama_budi_pekerti  \
# provinsi
# Prov. Aceh                                   76                      185
# Prov. Bali                                   20                       57
# Prov. Banten                                 69                      120
# Prov. Bengkulu                               19                       58
# Prov. D.I. Yogyakarta                        87                       80
# Prov. D.K.I. Jakarta                        144                      142
# Prov. Gorontalo                              15                       15
# Prov. Jambi                                  54                       66
# Prov. Jawa Barat                            191                      308
# Prov. Jawa Tengah                           121                      214
# Prov. Jawa Timur                            325                      393
# Prov. Kalimantan Barat                       30                       65
# Prov. Kalimantan Selatan                     46                       80
# Prov. Kalimantan Tengah                      22                       57
# Prov. Kalimantan Timur                       47                       45
# Prov. Kalimantan Utara                        4                       19
# Prov. Kepulauan Bangka Belitung              11                       23
# Prov. Kepulauan Riau                         27                       18
# Prov. Lampung                                17                       40
# Prov. Maluku                                  3                       22
# Prov. Maluku Utara                           12                       28
# Prov. Nusa Tenggara Barat                    81                      111
# Prov. Nusa Tenggara Timur                    97                      170
# Prov. Papua                                   1                        3
# Prov. Papua Barat                             0                        0
# Prov. Papua Barat Daya                        2                       10
# Prov. Papua Selatan                           1                        0
# Prov. Papua Tengah                            2                        6
# Prov. Riau                                   42                       85
# Prov. Sulawesi Barat                         16                       50
# Prov. Sulawesi Selatan                      102                      147
# Prov. Sulawesi Tengah                        29                       43
# Prov. Sulawesi Tenggara                      63                      106
# Prov. Sulawesi Utara                         19                       30
# Prov. Sumatera Barat                        131                      197
# Prov. Sumatera Selatan                       41                       93
# Prov. Sumatera Utara                         72                      126
#
#                                  guru_seni_budaya  ...  sumber_air_minum  \
# provinsi                                           ...
# Prov. Aceh                                     28  ...               0.0
# Prov. Bali                                     35  ...               0.0
# Prov. Banten                                   20  ...               0.0
# Prov. Bengkulu                                 17  ...               0.0
# Prov. D.I. Yogyakarta                          33  ...               0.0
# Prov. D.K.I. Jakarta                           32  ...               0.0
# Prov. Gorontalo                                 1  ...               0.0
# Prov. Jambi                                    47  ...               0.0
# Prov. Jawa Barat                               66  ...               0.0
# Prov. Jawa Tengah                              55  ...               0.0
# Prov. Jawa Timur                               70  ...               0.0
# Prov. Kalimantan Barat                          9  ...               0.0
# Prov. Kalimantan Selatan                       22  ...               0.0
# Prov. Kalimantan Tengah                         2  ...               0.0
# Prov. Kalimantan Timur                         23  ...               0.0
# Prov. Kalimantan Utara                          1  ...               0.0
# Prov. Kepulauan Bangka Belitung                 1  ...               0.0
# Prov. Kepulauan Riau                            8  ...               0.0
# Prov. Lampung                                   6  ...               0.0
# Prov. Maluku                                    3  ...               0.0
# Prov. Maluku Utara                              0  ...               0.0
# Prov. Nusa Tenggara Barat                      23  ...               0.0
# Prov. Nusa Tenggara Timur                      46  ...               0.0
# Prov. Papua                                     0  ...               0.0
# Prov. Papua Barat                               0  ...               0.0
# Prov. Papua Barat Daya                          0  ...               0.0
# Prov. Papua Selatan                             0  ...               0.0
# Prov. Papua Tengah                              0  ...               0.0
# Prov. Riau                                     18  ...               0.0
# Prov. Sulawesi Barat                           11  ...               0.0
# Prov. Sulawesi Selatan                         29  ...               0.0
# Prov. Sulawesi Tengah                          10  ...               0.0
# Prov. Sulawesi Tenggara                        36  ...               0.0
# Prov. Sulawesi Utara                           10  ...               0.0
# Prov. Sumatera Barat                           42  ...               0.0
# Prov. Sumatera Selatan                         17  ...               0.0
# Prov. Sumatera Utara                           27  ...               0.0
#
#                                  kecukupan_air_bersih  jamban_kk  tipe_jamban  \
# provinsi
# Prov. Aceh                                        0.0        0.0          0.0
# Prov. Bali                                        0.0        0.0          0.0
# Prov. Banten                                      0.0        0.0          0.0
# Prov. Bengkulu                                    0.0        0.0          0.0
# Prov. D.I. Yogyakarta                             0.0        0.0          0.0
# Prov. D.K.I. Jakarta                              0.0        0.0          0.0
# Prov. Gorontalo                                   0.0        0.0          0.0
# Prov. Jambi                                       0.0        0.0          0.0
# Prov. Jawa Barat                                  0.0        0.0          0.0
# Prov. Jawa Tengah                                 0.0        0.0          0.0
# Prov. Jawa Timur                                  0.0        0.0          0.0
# Prov. Kalimantan Barat                            0.0        0.0          0.0
# Prov. Kalimantan Selatan                          0.0        0.0          0.0
# Prov. Kalimantan Tengah                           0.0        0.0          0.0
# Prov. Kalimantan Timur                            0.0        0.0          0.0
# Prov. Kalimantan Utara                            0.0        0.0          0.0
# Prov. Kepulauan Bangka Belitung                   0.0        0.0          0.0
# Prov. Kepulauan Riau                              0.0        0.0          0.0
# Prov. Lampung                                     0.0        0.0          0.0
# Prov. Maluku                                      0.0        0.0          0.0
# Prov. Maluku Utara                                0.0        0.0          0.0
# Prov. Nusa Tenggara Barat                         0.0        0.0          0.0
# Prov. Nusa Tenggara Timur                         0.0        0.0          0.0
# Prov. Papua                                       0.0        0.0          0.0
# Prov. Papua Barat                                 0.0        0.0          0.0
# Prov. Papua Barat Daya                            0.0        0.0          0.0
# Prov. Papua Selatan                               0.0        0.0          0.0
# Prov. Papua Tengah                                0.0        0.0          0.0
# Prov. Riau                                        0.0        0.0          0.0
# Prov. Sulawesi Barat                              0.0        0.0          0.0
# Prov. Sulawesi Selatan                            0.0        0.0          0.0
# Prov. Sulawesi Tengah                             0.0        0.0          0.0
# Prov. Sulawesi Tenggara                           0.0        0.0          0.0
# Prov. Sulawesi Utara                              0.0        0.0          0.0
# Prov. Sumatera Barat                              0.0        0.0          0.0
# Prov. Sumatera Selatan                            0.0        0.0          0.0
# Prov. Sumatera Utara                              0.0        0.0          0.0
#
#                                  jml_hari_cuci_tangan  jml_wastafel  \
# provinsi
# Prov. Aceh                                        0.0           0.0
# Prov. Bali                                        0.0           0.0
# Prov. Banten                                      0.0           0.0
# Prov. Bengkulu                                    0.0           0.0
# Prov. D.I. Yogyakarta                             0.0           0.0
# Prov. D.K.I. Jakarta                              0.0           0.0
# Prov. Gorontalo                                   0.0           0.0
# Prov. Jambi                                       0.0           0.0
# Prov. Jawa Barat                                  0.0           0.0
# Prov. Jawa Tengah                                 0.0           0.0
# Prov. Jawa Timur                                  0.0           0.0
# Prov. Kalimantan Barat                            0.0           0.0
# Prov. Kalimantan Selatan                          0.0           0.0
# Prov. Kalimantan Tengah                           0.0           0.0
# Prov. Kalimantan Timur                            0.0           0.0
# Prov. Kalimantan Utara                            0.0           0.0
# Prov. Kepulauan Bangka Belitung                   0.0           0.0
# Prov. Kepulauan Riau                              0.0           0.0
# Prov. Lampung                                     0.0           0.0
# Prov. Maluku                                      0.0           0.0
# Prov. Maluku Utara                                0.0           0.0
# Prov. Nusa Tenggara Barat                         0.0           0.0
# Prov. Nusa Tenggara Timur                         0.0           0.0
# Prov. Papua                                       0.0           0.0
# Prov. Papua Barat                                 0.0           0.0
# Prov. Papua Barat Daya                            0.0           0.0
# Prov. Papua Selatan                               0.0           0.0
# Prov. Papua Tengah                                0.0           0.0
# Prov. Riau                                        0.0           0.0
# Prov. Sulawesi Barat                              0.0           0.0
# Prov. Sulawesi Selatan                            0.0           0.0
# Prov. Sulawesi Tengah                             0.0           0.0
# Prov. Sulawesi Tenggara                           0.0           0.0
# Prov. Sulawesi Utara                              0.0           0.0
# Prov. Sumatera Barat                              0.0           0.0
# Prov. Sumatera Selatan                            0.0           0.0
# Prov. Sumatera Utara                              0.0           0.0
#
#                                  jml_wastafel_rusak  air_mengalir_wastafel  \
# provinsi
# Prov. Aceh                                      0.0                    0.0
# Prov. Bali                                      0.0                    0.0
# Prov. Banten                                    0.0                    0.0
# Prov. Bengkulu                                  0.0                    0.0
# Prov. D.I. Yogyakarta                           0.0                    0.0
# Prov. D.K.I. Jakarta                            0.0                    0.0
# Prov. Gorontalo                                 0.0                    0.0
# Prov. Jambi                                     0.0                    0.0
# Prov. Jawa Barat                                0.0                    0.0
# Prov. Jawa Tengah                               0.0                    0.0
# Prov. Jawa Timur                                0.0                    0.0
# Prov. Kalimantan Barat                          0.0                    0.0
# Prov. Kalimantan Selatan                        0.0                    0.0
# Prov. Kalimantan Tengah                         0.0                    0.0
# Prov. Kalimantan Timur                          0.0                    0.0
# Prov. Kalimantan Utara                          0.0                    0.0
# Prov. Kepulauan Bangka Belitung                 0.0                    0.0
# Prov. Kepulauan Riau                            0.0                    0.0
# Prov. Lampung                                   0.0                    0.0
# Prov. Maluku                                    0.0                    0.0
# Prov. Maluku Utara                              0.0                    0.0
# Prov. Nusa Tenggara Barat                       0.0                    0.0
# Prov. Nusa Tenggara Timur                       0.0                    0.0
# Prov. Papua                                     0.0                    0.0
# Prov. Papua Barat                               0.0                    0.0
# Prov. Papua Barat Daya                          0.0                    0.0
# Prov. Papua Selatan                             0.0                    0.0
# Prov. Papua Tengah                              0.0                    0.0
# Prov. Riau                                      0.0                    0.0
# Prov. Sulawesi Barat                            0.0                    0.0
# Prov. Sulawesi Selatan                          0.0                    0.0
# Prov. Sulawesi Tengah                           0.0                    0.0
# Prov. Sulawesi Tenggara                         0.0                    0.0
# Prov. Sulawesi Utara                            0.0                    0.0
# Prov. Sumatera Barat                            0.0                    0.0
# Prov. Sumatera Selatan                          0.0                    0.0
# Prov. Sumatera Utara                            0.0                    0.0
#
#                                  memiliki_drainase  menguras_tangki_septik
# provinsi
# Prov. Aceh                                     0.0                     0.0
# Prov. Bali                                     0.0                     0.0
# Prov. Banten                                   0.0                     0.0
# Prov. Bengkulu                                 0.0                     0.0
# Prov. D.I. Yogyakarta                          0.0                     0.0
# Prov. D.K.I. Jakarta                           0.0                     0.0
# Prov. Gorontalo                                0.0                     0.0
# Prov. Jambi                                    0.0                     0.0
# Prov. Jawa Barat                               0.0                     0.0
# Prov. Jawa Tengah                              0.0                     0.0
# Prov. Jawa Timur                               0.0                     0.0
# Prov. Kalimantan Barat                         0.0                     0.0
# Prov. Kalimantan Selatan                       0.0                     0.0
# Prov. Kalimantan Tengah                        0.0                     0.0
# Prov. Kalimantan Timur                         0.0                     0.0
# Prov. Kalimantan Utara                         0.0                     0.0
# Prov. Kepulauan Bangka Belitung                0.0                     0.0
# Prov. Kepulauan Riau                           0.0                     0.0
# Prov. Lampung                                  0.0                     0.0
# Prov. Maluku                                   0.0                     0.0
# Prov. Maluku Utara                             0.0                     0.0
# Prov. Nusa Tenggara Barat                      0.0                     0.0
# Prov. Nusa Tenggara Timur                      0.0                     0.0
# Prov. Papua                                    0.0                     0.0
# Prov. Papua Barat                              0.0                     0.0
# Prov. Papua Barat Daya                         0.0                     0.0
# Prov. Papua Selatan                            0.0                     0.0
# Prov. Papua Tengah                             0.0                     0.0
# Prov. Riau                                     0.0                     0.0
# Prov. Sulawesi Barat                           0.0                     0.0
# Prov. Sulawesi Selatan                         0.0                     0.0
# Prov. Sulawesi Tengah                          0.0                     0.0
# Prov. Sulawesi Tenggara                        0.0                     0.0
# Prov. Sulawesi Utara                           0.0                     0.0
# Prov. Sumatera Barat                           0.0                     0.0
# Prov. Sumatera Selatan                         0.0                     0.0
# Prov. Sumatera Utara                           0.0                     0.0
#
# [37 rows x 96 columns]

# %% [markdown]
# ## Visualize top 10 most SLB students each province

# %%
df_indonesia_slb_20251_groupby_provinsi_sorted_by_pd_desc = df_indonesia_slb_20251_groupby_provinsi.sort_values(by='pd', ascending=False)
df_indonesia_slb_20251_groupby_provinsi_sorted_by_pd_desc.head()
# Out:
#                       rombel  guru_kelas  guru_matematika  \
# provinsi
# Prov. Jawa Barat        7821        4371               96
# Prov. Jawa Timur        5652        3238              199
# Prov. Jawa Tengah       3944        2109               65
# Prov. Banten            2073        1107               49
# Prov. Sumatera Barat    2160        1279               76
#
#                       guru_bahasa_indonesia  guru_bahasa_inggris  \
# provinsi
# Prov. Jawa Barat                         99                  116
# Prov. Jawa Timur                        198                  217
# Prov. Jawa Tengah                        45                   63
# Prov. Banten                             55                   35
# Prov. Sumatera Barat                     73                   87
#
#                       guru_sejarah_indonesia  guru_pkn  guru_penjaskes  \
# provinsi
# Prov. Jawa Barat                           0        47             191
# Prov. Jawa Timur                           0       168             325
# Prov. Jawa Tengah                          0        30             121
# Prov. Banten                               0        25              69
# Prov. Sumatera Barat                       0        53             131
#
#                       guru_agama_budi_pekerti  guru_seni_budaya  ...  \
# provinsi                                                         ...
# Prov. Jawa Barat                          308                66  ...
# Prov. Jawa Timur                          393                70  ...
# Prov. Jawa Tengah                         214                55  ...
# Prov. Banten                              120                20  ...
# Prov. Sumatera Barat                      197                42  ...
#
#                       sumber_air_minum  kecukupan_air_bersih  jamban_kk  \
# provinsi
# Prov. Jawa Barat                   0.0                   0.0        0.0
# Prov. Jawa Timur                   0.0                   0.0        0.0
# Prov. Jawa Tengah                  0.0                   0.0        0.0
# Prov. Banten                       0.0                   0.0        0.0
# Prov. Sumatera Barat               0.0                   0.0        0.0
#
#                       tipe_jamban  jml_hari_cuci_tangan  jml_wastafel  \
# provinsi
# Prov. Jawa Barat              0.0                   0.0           0.0
# Prov. Jawa Timur              0.0                   0.0           0.0
# Prov. Jawa Tengah             0.0                   0.0           0.0
# Prov. Banten                  0.0                   0.0           0.0
# Prov. Sumatera Barat          0.0                   0.0           0.0
#
#                       jml_wastafel_rusak  air_mengalir_wastafel  \
# provinsi
# Prov. Jawa Barat                     0.0                    0.0
# Prov. Jawa Timur                     0.0                    0.0
# Prov. Jawa Tengah                    0.0                    0.0
# Prov. Banten                         0.0                    0.0
# Prov. Sumatera Barat                 0.0                    0.0
#
#                       memiliki_drainase  menguras_tangki_septik
# provinsi
# Prov. Jawa Barat                    0.0                     0.0
# Prov. Jawa Timur                    0.0                     0.0
# Prov. Jawa Tengah                   0.0                     0.0
# Prov. Banten                        0.0                     0.0
# Prov. Sumatera Barat                0.0                     0.0
#
# [5 rows x 96 columns]

# %%
top10 = df_indonesia_slb_20251_groupby_provinsi_sorted_by_pd_desc.head(10)

plt.figure(figsize=(8, 5))
plt.barh(top10.index, top10['pd'])
plt.title("Top 10 Provinsi by PD (descending)")
plt.xlabel("Value")
plt.ylabel("Provinsi")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Visualize Top 10 Teachers each province

# %%
df_indonesia_slb_20251_groupby_provinsi_sorted_by_ptk_desc = df_indonesia_slb_20251_groupby_provinsi.sort_values(by='ptk', ascending=False)
df_indonesia_slb_20251_groupby_provinsi_sorted_by_ptk_desc.head()
# Out:
#                       rombel  guru_kelas  guru_matematika  \
# provinsi
# Prov. Jawa Barat        7821        4371               96
# Prov. Jawa Timur        5652        3238              199
# Prov. Jawa Tengah       3944        2109               65
# Prov. Sumatera Barat    2160        1279               76
# Prov. D.K.I. Jakarta    1395        1131              109
#
#                       guru_bahasa_indonesia  guru_bahasa_inggris  \
# provinsi
# Prov. Jawa Barat                         99                  116
# Prov. Jawa Timur                        198                  217
# Prov. Jawa Tengah                        45                   63
# Prov. Sumatera Barat                     73                   87
# Prov. D.K.I. Jakarta                    110                   31
#
#                       guru_sejarah_indonesia  guru_pkn  guru_penjaskes  \
# provinsi
# Prov. Jawa Barat                           0        47             191
# Prov. Jawa Timur                           0       168             325
# Prov. Jawa Tengah                          0        30             121
# Prov. Sumatera Barat                       0        53             131
# Prov. D.K.I. Jakarta                       0       160             144
#
#                       guru_agama_budi_pekerti  guru_seni_budaya  ...  \
# provinsi                                                         ...
# Prov. Jawa Barat                          308                66  ...
# Prov. Jawa Timur                          393                70  ...
# Prov. Jawa Tengah                         214                55  ...
# Prov. Sumatera Barat                      197                42  ...
# Prov. D.K.I. Jakarta                      142                32  ...
#
#                       sumber_air_minum  kecukupan_air_bersih  jamban_kk  \
# provinsi
# Prov. Jawa Barat                   0.0                   0.0        0.0
# Prov. Jawa Timur                   0.0                   0.0        0.0
# Prov. Jawa Tengah                  0.0                   0.0        0.0
# Prov. Sumatera Barat               0.0                   0.0        0.0
# Prov. D.K.I. Jakarta               0.0                   0.0        0.0
#
#                       tipe_jamban  jml_hari_cuci_tangan  jml_wastafel  \
# provinsi
# Prov. Jawa Barat              0.0                   0.0           0.0
# Prov. Jawa Timur              0.0                   0.0           0.0
# Prov. Jawa Tengah             0.0                   0.0           0.0
# Prov. Sumatera Barat          0.0                   0.0           0.0
# Prov. D.K.I. Jakarta          0.0                   0.0           0.0
#
#                       jml_wastafel_rusak  air_mengalir_wastafel  \
# provinsi
# Prov. Jawa Barat                     0.0                    0.0
# Prov. Jawa Timur                     0.0                    0.0
# Prov. Jawa Tengah                    0.0                    0.0
# Prov. Sumatera Barat                 0.0                    0.0
# Prov. D.K.I. Jakarta                 0.0                    0.0
#
#                       memiliki_drainase  menguras_tangki_septik
# provinsi
# Prov. Jawa Barat                    0.0                     0.0
# Prov. Jawa Timur                    0.0                     0.0
# Prov. Jawa Tengah                   0.0                     0.0
# Prov. Sumatera Barat                0.0                     0.0
# Prov. D.K.I. Jakarta                0.0                     0.0
#
# [5 rows x 96 columns]

# %%
top10 = df_indonesia_slb_20251_groupby_provinsi_sorted_by_ptk_desc.head(10)

plt.figure(figsize=(8, 5))
plt.barh(top10.index, top10['ptk'])
plt.title("Top 10 Provinsi by PD (descending)")
plt.xlabel("Value")
plt.ylabel("Provinsi")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # SLB Students Year by Year

# %% [markdown]
# ## Jawa Timur

# %%
jatim_csv_files = glob.glob('../data/dapo-kemdikdasmen/*/Prov. Jawa Timur/ALL/jatim-csv.csv')

df_jatim_list = []

for file in jatim_csv_files:
    df = pd.read_csv(file)
    
    df['semester_id'] = Path(file).parent.parent.parent.stem
    
    df_jatim_list.append(df)

df_slb_jatim_yby = pd.concat(df_jatim_list, ignore_index=True)
df_slb_jatim_yby
# Out:
#        kabupaten/kota       kecamatan                       sekolah  rombel  \
# 0      Kab. Bangkalan  Kec. Bangkalan          SLB SAMUDRA LAVENDER      21
# 1      Kab. Bangkalan      Kec. Kamal                      SLB PGRI      11
# 2      Kab. Bangkalan      Kec. Socah  SLB NEGERI KELEYAN BANGKALAN      30
# 3      Kab. Bangkalan     Kec. Tragah      SLB SAMUDRA TERRA ATHENA       6
# 4     Kab. Banyuwangi  Kec. Bangorejo            SLB PGRI BANGOREJO      12
# ...               ...             ...                           ...     ...
# 1970    Kota Surabaya   Kec. Wonocolo       SLB KHUSUS BINA MANDIRI      10
# 1971    Kota Surabaya  Kec. Wonokromo   SDLB-B KARYA MULIA SURABAYA       7
# 1972    Kota Surabaya  Kec. Wonokromo          SLB-B KARYA MULIA IV       5
# 1973    Kota Surabaya  Kec. Wonokromo           SMALB-B KARYA MULIA      12
# 1974    Kota Surabaya  Kec. Wonokromo           SMPLB B KARYA MULIA       8
#
#       guru_kelas  guru_matematika  guru_bahasa_indonesia  guru_bahasa_inggris  \
# 0             11                0                      0                    0
# 1              5                0                      0                    0
# 2             23                0                      0                    0
# 3              6                0                      0                    0
# 4             11                0                      0                    0
# ...          ...              ...                    ...                  ...
# 1970           7                0                      0                    0
# 1971           7                0                      0                    0
# 1972           5                0                      0                    0
# 1973           5                0                      1                    0
# 1974           7                1                      1                    1
#
#       guru_sejarah_indonesia  guru_pkn  ...  jml_hari_cuci_tangan  \
# 0                          0         0  ...                   NaN
# 1                          0         0  ...                   NaN
# 2                          0         0  ...                   NaN
# 3                          0         0  ...                   NaN
# 4                          0         0  ...                   NaN
# ...                      ...       ...  ...                   ...
# 1970                       0         1  ...                   NaN
# 1971                       0         7  ...                   NaN
# 1972                       0         0  ...                   NaN
# 1973                       0         1  ...                   NaN
# 1974                       0         1  ...                   NaN
#
#       jml_wastafel  jml_wastafel_rusak  air_mengalir_wastafel  \
# 0              NaN                 NaN                    NaN
# 1              NaN                 NaN                    NaN
# 2              NaN                 NaN                    NaN
# 3              NaN                 NaN                    NaN
# 4              NaN                 NaN                    NaN
# ...            ...                 ...                    ...
# 1970           NaN                 NaN                    NaN
# 1971           NaN                 NaN                    NaN
# 1972           NaN                 NaN                    NaN
# 1973           NaN                 NaN                    NaN
# 1974           NaN                 NaN                    NaN
#
#       memiliki_drainase  menguras_tangki_septik        npsn  \
# 0                   NaN                     NaN         NaN
# 1                   NaN                     NaN         NaN
# 2                   NaN                     NaN         NaN
# 3                   NaN                     NaN         NaN
# 4                   NaN                     NaN         NaN
# ...                 ...                     ...         ...
# 1970                NaN                     NaN  20532450.0
# 1971                NaN                     NaN  20532842.0
# 1972                NaN                     NaN  20532842.0
# 1973                NaN                     NaN  20532842.0
# 1974                NaN                     NaN  20532842.0
#
#       bentuk_pendidikan  status_sekolah  akreditasi
# 0                   NaN             NaN         NaN
# 1                   NaN             NaN         NaN
# 2                   NaN             NaN         NaN
# 3                   NaN             NaN         NaN
# 4                   NaN             NaN         NaN
# ...                 ...             ...         ...
# 1970                SLB          Swasta           B
# 1971                SLB          Swasta           B
# 1972                SLB          Swasta           B
# 1973                SLB          Swasta           A
# 1974                SLB          Swasta           A
#
# [1975 rows x 103 columns]

# %%
summed_by_semester_id = df_slb_jatim_yby.groupby('semester_id').sum(numeric_only=True)
summed_by_semester_id
# Out:
#              rombel  guru_kelas  guru_matematika  guru_bahasa_indonesia  \
# semester_id
# 2023-1         5208        3340              244                    260
# 2023-2         5311        3297              214                    209
# 2024-1         5418        3315              209                    199
# 2024-2         5559        3278              197                    196
# 2025-1         5500        3171              190                    188
#
#              guru_bahasa_inggris  guru_sejarah_indonesia  guru_pkn  \
# semester_id
# 2023-1                       223                       0       279
# 2023-2                       187                       0       240
# 2024-1                       228                       0       180
# 2024-2                       205                       0       163
# 2025-1                       207                       0       166
#
#              guru_penjaskes  guru_agama_budi_pekerti  guru_seni_budaya  ...  \
# semester_id                                                             ...
# 2023-1                  465                      706               244  ...
# 2023-2                  428                      649               168  ...
# 2024-1                  430                      562               160  ...
# 2024-2                  357                      492               138  ...
# 2025-1                  321                      385                69  ...
#
#              kecukupan_air_bersih  jamban_kk  tipe_jamban  \
# semester_id
# 2023-1                        0.0        0.0          0.0
# 2023-2                        0.0        0.0          0.0
# 2024-1                        0.0        0.0          0.0
# 2024-2                        0.0        0.0          0.0
# 2025-1                        0.0        0.0          0.0
#
#              jml_hari_cuci_tangan  jml_wastafel  jml_wastafel_rusak  \
# semester_id
# 2023-1                        0.0           0.0                 0.0
# 2023-2                        0.0           0.0                 0.0
# 2024-1                        0.0           0.0                 0.0
# 2024-2                        0.0           0.0                 0.0
# 2025-1                        0.0           0.0                 0.0
#
#              air_mengalir_wastafel  memiliki_drainase  menguras_tangki_septik  \
# semester_id
# 2023-1                         0.0                0.0                     0.0
# 2023-2                         0.0                0.0                     0.0
# 2024-1                         0.0                0.0                     0.0
# 2024-2                         0.0                0.0                     0.0
# 2025-1                         0.0                0.0                     0.0
#
#                      npsn
# semester_id
# 2023-1       0.000000e+00
# 2023-2       0.000000e+00
# 2024-1       0.000000e+00
# 2024-2       0.000000e+00
# 2025-1       1.313454e+10
#
# [5 rows x 95 columns]

# %% [markdown]
# ### Total Students Year by Year

# %%
# calculate year-over-year percentage change `pd` and `ptk``
summed_by_semester_id['persentase_kenaikan_pd'] = summed_by_semester_id['pd'].pct_change() * 100
summed_by_semester_id['persentase_kenaikan_ptk'] = summed_by_semester_id['ptk'].pct_change() * 100
summed_by_semester_id.to_csv('../outputs/data-jatim-group-by-semester-id.csv')
summed_by_semester_id
# Out:
#              rombel  guru_kelas  guru_matematika  guru_bahasa_indonesia  \
# semester_id
# 2023-1         5208        3340              244                    260
# 2023-2         5311        3297              214                    209
# 2024-1         5418        3315              209                    199
# 2024-2         5559        3278              197                    196
# 2025-1         5500        3171              190                    188
#
#              guru_bahasa_inggris  guru_sejarah_indonesia  guru_pkn  \
# semester_id
# 2023-1                       223                       0       279
# 2023-2                       187                       0       240
# 2024-1                       228                       0       180
# 2024-2                       205                       0       163
# 2025-1                       207                       0       166
#
#              guru_penjaskes  guru_agama_budi_pekerti  guru_seni_budaya  ...  \
# semester_id                                                             ...
# 2023-1                  465                      706               244  ...
# 2023-2                  428                      649               168  ...
# 2024-1                  430                      562               160  ...
# 2024-2                  357                      492               138  ...
# 2025-1                  321                      385                69  ...
#
#              tipe_jamban  jml_hari_cuci_tangan  jml_wastafel  \
# semester_id
# 2023-1               0.0                   0.0           0.0
# 2023-2               0.0                   0.0           0.0
# 2024-1               0.0                   0.0           0.0
# 2024-2               0.0                   0.0           0.0
# 2025-1               0.0                   0.0           0.0
#
#              jml_wastafel_rusak  air_mengalir_wastafel  memiliki_drainase  \
# semester_id
# 2023-1                      0.0                    0.0                0.0
# 2023-2                      0.0                    0.0                0.0
# 2024-1                      0.0                    0.0                0.0
# 2024-2                      0.0                    0.0                0.0
# 2025-1                      0.0                    0.0                0.0
#
#              menguras_tangki_septik          npsn  persentase_kenaikan_pd  \
# semester_id
# 2023-1                          0.0  0.000000e+00                     NaN
# 2023-2                          0.0  0.000000e+00                0.570781
# 2024-1                          0.0  0.000000e+00                1.409846
# 2024-2                          0.0  0.000000e+00               -0.235409
# 2025-1                          0.0  1.313454e+10                0.605494
#
#              persentase_kenaikan_ptk
# semester_id
# 2023-1                           NaN
# 2023-2                     -2.179763
# 2024-1                      0.687758
# 2024-2                      1.284153
# 2025-1                     -0.296736
#
# [5 rows x 97 columns]

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Left y-axis → total students
ax1.plot(
    summed_by_semester_id.index,
    summed_by_semester_id['pd'],
    marker='o',
    color='blue',
    label='Total Siswa SLB'
)
ax1.set_xlabel("Semester")
ax1.set_ylabel("Total Siswa SLB", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True)

# Right y-axis → percentage increase
ax2 = ax1.twinx()
ax2.plot(
    summed_by_semester_id.index,
    summed_by_semester_id['persentase_kenaikan_pd'],
    marker='s',
    linestyle='--',
    color='red',
    label='Persentase Kenaikan'
)
ax2.set_ylabel("Persentase Kenaikan (%)", color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Title
plt.title("Total Siswa SLB dan Persentase Kenaikan dari Tahun ke Tahun")

# Legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc="upper left")

plt.show()

# %% [markdown]
# ### Total Teachers Year by Year

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Left y-axis → total teachers
ax1.plot(
    summed_by_semester_id.index,
    summed_by_semester_id['ptk'],
    marker='o',
    color='green',
    label='Total Guru SLB'
)
ax1.set_xlabel("Semester")
ax1.set_ylabel("Total Guru SLB", color='green')
ax1.tick_params(axis='y', labelcolor='green')
ax1.grid(True)

# Right y-axis → percentage increase
ax2 = ax1.twinx()
ax2.plot(
    summed_by_semester_id.index,
    summed_by_semester_id['persentase_kenaikan_ptk'],
    marker='s',
    linestyle='--',
    color='orange',
    label='Persentase Kenaikan Guru'
)
ax2.set_ylabel("Persentase Kenaikan (%)", color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Title
plt.title("Total Guru SLB dan Persentase Kenaikan dari Tahun ke Tahun")

# Legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc="upper left")

plt.show()
